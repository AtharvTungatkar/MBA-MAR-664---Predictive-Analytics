# %%
import numpy as np
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# 'c:\\Users\\athar\\myfiles\\Assignments'

# %%
os.chdir("../")

# %%
os.getcwd()
# Out:
# 'c:\\Users\\athar\\myfiles'

# %%
data=pd.read_csv('Datasets/employee_attrition.csv')
data.head(2)
# Out:
#    age gender              department  years  performance    jobsat    income  \
# 0   39   Male         Human Resources     17     4.298854  3.260216  147094.0
# 1   29   Male  Research & Development     12     2.397524  4.864564   30997.0
#
#    distance  attrition
# 0      10.0          0
# 1       4.8          0

# %% [markdown]
# Question 1

# %%
train=data.sample(frac=0.7,random_state=617)
test=data.drop(labels=train.index)

# %%
((train.attrition.sum()/len(train))*100).round(4)
# Out:
# 20.7038

# %% [markdown]
# Question 2

# %%
train[train.attrition==1]['age'].mean().round(4)
# Out:
# 48.3046

# %% [markdown]
# Question 3 and Questuion 4

# %%
from statsmodels.formula.api import logit

log_model=logit('attrition ~ age',data=train)
model1=log_model.fit()

model1.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.508702
#          Iterations 5
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:              attrition   No. Observations:                 2188
# Model:                          Logit   Df Residuals:                     2186
# Method:                           MLE   Df Model:                            1
# Date:                Sun, 02 Nov 2025   Pseudo R-squ.:                0.002557
# Time:                        15:31:44   Log-Likelihood:                -1113.0
# converged:                       True   LL-Null:                       -1115.9
# Covariance Type:            nonrobust   LLR p-value:                   0.01690
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
model1.predict(pd.DataFrame({"age":[train['age'][0]]})).round(4)
# Out:
# 0    0.1888
# dtype: float64

# %% [markdown]
# Question 5

# %%
model1.predict(pd.DataFrame({"age":[60]})).round(4)
# Out:
# 0    0.235
# dtype: float64

# %% [markdown]
# Question 6

# %%
# Percent change in odds= (e^beta1 - 1)*100

((np.exp(model1.params[1])-1)*100).round(4)
# Out:
# C:\Users\athar\AppData\Local\Temp\ipykernel_11840\3262267189.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ((np.exp(model1.params[1])-1)*100).round(4)
# 1.3324

# %%
# Question 4 is wrong
