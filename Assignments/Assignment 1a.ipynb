# %%
type(1234/5678)
# Out:
# float

# %%
lst=[1,2,3,4]
lst
# Out:
# [1, 2, 3, 4]

# %%
lst.pop()
# Out:
# 4

# %%
dict1={'name':'Atharv','Age':24,'Major':'MBA Business Analytics'}

# %%
'name' in dict1.values()
# Out:
# False

# %%
dict1.has_key('name')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 dict1.has_key('name')
#
# AttributeError: 'dict' object has no attribute 'has_key'

# %%
'name' in dict1
# Out:
# True

# %%
dict1.contains('name')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 dict1.contains('name')
#
# AttributeError: 'dict' object has no attribute 'contains'
