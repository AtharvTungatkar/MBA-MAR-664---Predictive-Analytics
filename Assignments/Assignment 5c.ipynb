# %%
import numpy as np
import pandas as pd
import os

os.chdir("../")
os.getcwd()
# Out:
# 'e:\\MBA-MAR-664---Predictive-Analytics'

# %%
data=pd.read_csv('Datasets/employee_attrition.csv')

# %%
data.head(1)
# Out:
#    age gender       department  years  performance    jobsat    income  \
# 0   39   Male  Human Resources     17     4.298854  3.260216  147094.0
#
#    distance  attrition
# 0      10.0          0

# %% [markdown]
# Question 1

# %%
from sklearn.model_selection import train_test_split

y = data.attrition
X = data.drop(['attrition'], axis = 1)
from sklearn.model_selection import train_test_split
X_train_raw, X_test_raw, y_train, y_test = train_test_split(X, y, 
                                                            random_state=617, 
                                                            train_size=0.8, 
                                                            stratify=y)

# %%
(sum(y_train)/len(y_train))*100
# Out:
# 20.52

# %% [markdown]
# Question 2

# %%
X_train_raw.head(1)
# Out:
#       age gender department  years  performance  jobsat   income  distance
# 1089   44   Male      Sales      2     2.324964  3.4019  53977.0       0.5

# %%
categorical_features = X_train_raw.select_dtypes('object').columns

X_train = pd.get_dummies(X_train_raw, 
                         prefix_sep = '_', 
                         columns = categorical_features, 
                         drop_first = True)

X_test = pd.get_dummies(X_test_raw, 
                         prefix_sep = '_', 
                         columns = categorical_features, 
                         drop_first = True)

X_test = X_test.reindex(columns=X_train.columns, fill_value=0)
X_train.head()
# Out:
#       age  years  performance    jobsat   income  distance  gender_Male  \
# 1089   44      2     2.324964  3.401900  53977.0       0.5         True
# 3073   49      2     2.900507  3.012745  67385.0      12.4        False
# 246    45     11     3.728783  1.095224  49781.0       6.0         True
# 80     46      2     4.135223  3.978233  46139.0      11.7        False
# 2533   53      4     3.002379  2.517982  41114.0       4.5         True
#
#       department_Research & Development  department_Sales
# 1089                              False              True
# 3073                              False             False
# 246                                True             False
# 80                                False              True
# 2533                               True             False

# %%
X_train.gender_Male.mean()
# Out:
# 0.6012

# %% [markdown]
# Question 3

# %%
from sklearn.linear_model import LogisticRegression

logit = LogisticRegression(max_iter=10000, random_state=617)
logit.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=10000, random_state=617)

# %%
y_pred_proba = logit.predict_proba(X_train)
y_pred_proba[0]
# Out:
# array([0.99383588, 0.00616412])

# %%
y_pred = logit.predict(X_train)
y_pred[0]
# Out:
# 0

# %% [markdown]
# Question 4

# %%
from sklearn.metrics import recall_score

sensitivity_or_recall = recall_score(y_train, y_pred)
sensitivity_or_recall.round(4)
# Out:
# 0.4932

# %% [markdown]
# Question 5

# %%
y_pred_test = logit.predict(X_test)
sensitivity_or_recall_test = recall_score(y_test, y_pred_test)
sensitivity_or_recall_test.round(4)
# Out:
# 0.5234

# %% [markdown]
# Question 6

# %%
from sklearn.metrics import roc_auc_score

auc_train = roc_auc_score(y_train, y_pred)
auc_train.round(4)
# Out:
# 0.7202

# %% [markdown]
# Question 7

# %%
auc_test = roc_auc_score(y_test, y_pred_test)
auc_test.round(4)
# Out:
# 0.7315

# %%
# Question 6 and Question 7 are wrong

# %%
# Question 6
y_pred_prob_train=logit.predict_proba(X_train)
auc_train = roc_auc_score(y_train, y_pred_prob_train[:,1])
auc_train.round(4)
# Out:
# 0.879

# %%
# Question 6
y_pred_prob_test=logit.predict_proba(X_test)
auc_test = roc_auc_score(y_test, y_pred_prob_test[:,1])
auc_test.round(4)
# Out:
# 0.8833

# %%
## Everything is correct
