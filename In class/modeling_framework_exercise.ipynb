# %% [markdown]
# # In-Class Exercise: Modeling Framework
#
# We will use the dataset `sales_toy.csv` to practice splitting data and evaluating models with performance metrics.

# %% [markdown]
# ## 1) Load and Inspect Data
# Load `sales_toy.csv` and show the first 5 rows.

# %%
# Load dataset

# %% [markdown]
# ## 2) Define Features and Target
# Set X to include region, marketing_spend and competitors' and y to sales.

# %%
# Define X and y

# %% [markdown]
# ## 3) Train-Test Split
# Split the dataset into 75% training and 25% testing with random_state=1.

# %%
# Train-test split

# %% [markdown]
# ## 4) Multiple Splits
# Perform a train-test split with random_state=617. Print the mean of y_train.

# %%
# Train-test split

# %% [markdown]
# ## 5) Train-Validation-Test Split
# Perform a train-test split with random_state=1031. Print the mean of y_train.

# %%
# Train-test split

# %% [markdown]
# ## 6) Accuracy (Classification Example)
# Assume true=[1,0,1,1,0,0,1,0], pred=[1,0,0,1,0,1,1,0]. Compute accuracy.

# %%
# Accuracy score

# %% [markdown]
# ## 7) Precision (Classification Example)
# Using the same values, compute precision.

# %%
# Precision score

# %% [markdown]
# ## 8) Recall (Classification Example)
# Using the same values, compute recall.

# %%
# Recall score

# %% [markdown]
# ## 9) Regression Metric – RMSE
# Given true=[100,150,200,250], pred=[110,140,190,260], compute RMSE.

# %%
# RMSE

# %% [markdown]
# ## 10) Regression Metrics – MAE & R²
# Using the same values, compute MAE and R².

# %%
# MAE and R²
